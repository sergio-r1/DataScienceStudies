# %%
# importação das bibliotecas, sklearn para criar o modelo de regressão e yellowbrick para a visualização dos residuais 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
base = pd.read_csv('reglog.csv')
plt.scatter(base.x, base.y)
base.describe()
# Out:
#                  x            y
# count  1000.000000  1000.000000
# mean    499.500000     0.463429
# std     288.819436     0.272852
# min       0.000000     0.000068
# 25%     249.750000     0.247269
# 50%     499.500000     0.433808
# 75%     749.250000     0.688680
# max     999.000000     0.998805

# %%
np.corrcoef(base.x, base.y)
# Out:
# array([[1.        , 0.85857041],
#        [0.85857041, 1.        ]])
