# %%
# importação das bibliotecas, sklearn para criar o modelo de regressão e yellowbrick para a visualização dos residuais 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
base = pd.read_csv('../Dados/teste.csv')
plt.scatter(base.x, base.y)
base.describe()
# Out:
#                  x            y
# count  1000.000000  1000.000000
# mean    499.500000   142.233272
# std     288.819436   111.204823
# min       0.000000     0.000000
# 25%     249.750000    31.015746
# 50%     499.500000   142.001922
# 75%     749.250000   221.665739
# max     999.000000   470.600958

# %%
np.corrcoef(base.x, base.y)
# Out:
# array([[1.        , 0.68265856],
#        [0.68265856, 1.        ]])
