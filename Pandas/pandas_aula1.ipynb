# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
# pd.read_csv('aluguel.csv', sep=';') #faz a leitura

dados = pd.read_csv('aluguel.csv', sep=';') #faz a leitura e atribui a variavel "dados"

# %%
# Mostra os n primeiros arquivos do arquivo csv
dados.head(15)
# Out:
#                        Tipo               Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete           Copacabana        1      0       0
# 1                      Casa      Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala      Barra da Tijuca        0      4       0
# 3               Apartamento               Centro        1      0       0
# 4               Apartamento         Higienópolis        1      0       0
# 5               Apartamento         Vista Alegre        3      1       0
# 6               Apartamento             Cachambi        2      0       0
# 7        Casa de Condomínio      Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                Ramos        2      2       0
# 9   Conjunto Comercial/Sala               Centro        0      3       0
# 10              Apartamento               Centro        1      0       0
# 11              Apartamento               Grajaú        2      1       0
# ...

# %% [markdown]
# ## Informações gerais sobre a brase de dados

# %%
# mostra os tipos de dados de cada objeto
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
# PAra mostrar de forma mais elegante
tipos_de_dados = pd.DataFrame(dados.dtypes, columns=['Tipos de Dados'])
tipos_de_dados.columns.name = "Variaveis"

# Para mostrar o resultado
tipos_de_dados
# Out:
# Variaveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
# Retorna uma tupla com o numero de linhas e a quantidade de colunas
dados.shape

#Para acessar essas informações de forma individual
dados.shape[0]
dados.shape[1]

print(f"A base apresenta {dados.shape[0]} registros e {dados.shape[1]} variaveis")
# Out:
# A base apresenta 32960 registros e 9 variaveis
